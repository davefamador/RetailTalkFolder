# %% [markdown]
# # Data Cleaning — IntentDataset.xlsx
#
# This notebook performs data cleaning on `IntentDataset.xlsx`:
# - Load the dataset
# - Identify and remove duplicate rows
# - Save the cleaned dataset

# %%
import pandas as pd
import os

# %% [markdown]
# ## 1. Load the Dataset

# %%
DATASET_DIR = r"c:\Moi\Thesis\Code\RetailTalkFolder\shopping_queries_dataset"
FILE_PATH = os.path.join(DATASET_DIR, "IntentDataset.xlsx")

df = pd.read_excel(FILE_PATH, engine='openpyxl')
print(f"Original shape: {df.shape}")
df.head()
# Out:
# Original shape: (39953, 5)
#                       query  single_search  multi_search  filtered_search  \
# 0     sardines canned goods              1             0                0
# 1  Lucky Me instant noodles              1             0                0
# 2      3 in 1 coffee sachet              1             0                0
# 3    powdered milk for kids              1             0                0
# 4       cooking oil 1 liter              1             0                0
#
#    free_form
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# ## 2. Inspect for Duplicates

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 237

# %%
if num_duplicates > 0:
    print("Duplicate rows:")
    display(df[df.duplicated(keep=False)].sort_values(by=df.columns.tolist()))
else:
    print("No duplicate rows found.")
# Out:
# Duplicate rows:
#                            query  single_search  multi_search  \
# 20069                  air fryer              1             0
# 29726                  air fryer              1             0
# 23651     air fryer and backpack              0             1
# 32246     air fryer and backpack              0             1
# 22384    air fryer and face wash              0             1
# ...                          ...            ...           ...
# 30612   what is a good sunscreen              1             0
# 12098     what is a good t-shirt              1             0
# 34950     what is a good t-shirt              1             0
# 10264  what is a good toothpaste              1             0
# 30857  what is a good toothpaste              1             0
#
#        filtered_search  free_form
# 20069                0          0
# 29726                0          0
# 23651                0          0
# 32246                0          0
# ...

# %% [markdown]
# ## 3. Remove Duplicates

# %%
df_cleaned = df.drop_duplicates()
rows_removed = len(df) - len(df_cleaned)
print(f"Rows removed: {rows_removed}")
print(f"Cleaned shape: {df_cleaned.shape}")
# Out:
# Rows removed: 237
# Cleaned shape: (39716, 5)

# %% [markdown]
# ## 4. Save Cleaned Dataset

# %%
OUTPUT_PATH = os.path.join(DATASET_DIR, "IntentDataset_cleaned.xlsx")

df_cleaned.to_excel(OUTPUT_PATH, index=False, engine='openpyxl')
print(f"Cleaned dataset saved to: {OUTPUT_PATH}")
# Out:
# Cleaned dataset saved to: c:\Moi\Thesis\Code\RetailTalkFolder\shopping_queries_dataset\IntentDataset_cleaned.xlsx

# %%
# Quick verification
df_verify = pd.read_excel(OUTPUT_PATH, engine='openpyxl')
print(f"Verified shape: {df_verify.shape}")
print(f"Remaining duplicates: {df_verify.duplicated().sum()}")
# Out:
# Verified shape: (39716, 5)
# Remaining duplicates: 0
